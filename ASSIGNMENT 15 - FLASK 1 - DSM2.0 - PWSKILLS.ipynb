# %% [markdown]
# # ASSIGNMENT 15 - FLASK 1 - DSM2.0 - PWSKILLS

# %% [markdown]
# ### Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# 'Flask' is used in python, it is used to make we API and applications.
# Advantages _
# 1. Simplicity
# 2. Flexibility
# 3. Plugins

# %% [markdown]
# ### Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %% [markdown]
# ![download.png](attachment:download.png)

# %%
#Code -
from flask import Flask
from flask import request

app = Flask(__name__)

@app.route("/")
def helloworld():
    return "<h1>Hello World</h1>"


if __name__ == "__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![Screenshot%20%2822%29.png](attachment:Screenshot%20%2822%29.png)

# %% [markdown]
# ### Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# App routing is used to map functions to the URLs.
# To create different routes for different parts of the application.
# We can decide which function to be used when which url is used.
# To handle different request based on the values.
# App routes in Flask provide a way to handle different URLs and define the corresponding actions or responses, making it easier to navigate and interact with our web application.

# %% [markdown]
# ### Q4.  Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”route to show the following details:
#
#     Company Name: ABC Corporation
#
#     Location: India
#
#     Contact Detail: 999-999-9999

# %%
#Code - 

from flask import Flask
from flask import request

app = Flask(__name__)

@app.route("/")
def helloworld():
    return "<p>Company Name: ABC Corporation</p> <br> <p>Location: India</p> <br> <p>Contact Detail: 999-999-9999</p>"

@app.route("/welcome")
def welcom():
    return "<h2>Welcome to ABC Corporation</h2>"


if __name__ == "__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![Screenshot%20%2826%29.png](attachment:Screenshot%20%2826%29.png)

# %% [markdown]
# ![Screenshot%20%2824%29.png](attachment:Screenshot%20%2824%29.png)

# %% [markdown]
# ![Screenshot%20%2825%29.png](attachment:Screenshot%20%2825%29.png)

# %% [markdown]
# ### Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# Flask url_for is defined as a function that enables developers to build and generate URLs on a Flask application

# %%
from flask import Flask
from flask import request
from flask import  redirect, url_for

app = Flask(__name__)

@app.route("/helloworld")
def helloworld():
    return "<p>Company Name: ABC Corporation</p> <br> <p>Location: India</p> <br> <p>Contact Detail: 999-999-9999</p>"

@app.route("/welcome/<details>")
def welcom(details):
    if details=='True':
        return redirect(url_for('helloworld')) #on details = True, the server will direct the 
                                               #client to the url of helloworld() function
    else:
        return "<p>Faliure</p>"

if __name__ == "__main__":
    app.run(host="0.0.0.0")
